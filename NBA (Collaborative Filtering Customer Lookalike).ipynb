# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def combine_features(row):
    return row['category'] + row['subcategory'] + row['']

# %%
nba = pd.read_csv('malaysia_data/customer_receipt_product.csv', error_bad_lines=False)
now = pd.Timestamp('now')
nba['age'] = (now - pd.to_datetime(nba['dob'], format='%Y-%m-%d')).astype('<m8[Y]')

# %%
nba.head()
# Out:
#                  customerid                             receiptid  \
# 0  5ae965218e3795fb61cbda69  1c3fd0dd-4cc2-4565-8be8-9bde1daeece5
# 1  5ae965218e3795fb61cbda6a  8f226466-58fe-4cea-84af-939d653f7f45
# 2  5ae965218e3795fb61cbda6b  155e7278-f7e8-4165-9b58-04fa2497b112
# 3  5ae965218e3795fb61cbda6b  2330c6cb-196d-4dc7-a191-07086708ff3e
# 4  5ae965218e3795fb61cbda6b  155e7278-f7e8-4165-9b58-04fa2497b112
#
#                               productid            category  \
# 0  1a5ae34b-cdbf-4827-b051-122eea978c32            Beverage
# 1  47a327b5-f8a0-4b37-9688-4f709b1297f2       Personal Care
# 2  e4fa20e3-585f-4af0-b70d-33fceab0ee8f         Canned Food
# 3  d696ac67-c163-4306-baec-a3aa02ae56be         Milk Powder
# 4  839d5ad5-244d-47ac-818e-adab309dd590  Household Products
#
#                 subcategory                                          prodname  \
# 0    Pre-School 3yr onwards                           Pediasure Complete 850g
# 1  Anti-bacterial Wet Wipes                Antabax Cleansing Wipes 10s X 3pck
# 2      Mackarel/ CuttleFish  Ayam Brand Black Beans Spicy Fried Mackerel 150g
# 3           Growing Up MIlk                   Enfagrow A+ Step 4 Vanilla 600g
# 4         Dishwashing Paste                      Axion Dishwashing Paste 750g
#
#    prodqty  produnitprice  produnitdiscount  \
# 0      1.0         158.16               NaN
# 1      1.0           4.52               NaN
# 2      1.0           5.45               NaN
# 3      1.0         243.30               NaN
# 4      1.0           5.65               NaN
#
#                        productdetailsid  ...           names gender     race  \
# 0  49bcffa0-4822-4262-bc61-f658482020d9  ...  Denise Mccarty      F  CHINESE
# 1  3cd77559-c3d3-4fe2-85c5-2a41e5aaad1c  ...     Juan Norman      F    MALAY
# 2  7d4487e6-3b18-4241-a80d-342de867a0ab  ...     Paula Gates      F  CHINESE
# 3  7e39d27e-d6f4-417e-830c-0a922f839bb8  ...     Paula Gates      F  CHINESE
# 4  44c0b518-9564-4b63-9ec3-88a3de85c7d4  ...     Paula Gates      F  CHINESE
#
#           dob  joineddate  emaildomain     city postcode     state   age
# 0  1990-07-20  2018-01-17  hotmail.com     Ipoh  31350.0     Perak  28.0
# 1  1989-03-26  2018-03-09    gmail.com  Puchong  47100.0  Selangor  30.0
# 2  1982-09-20  2017-11-02    yahoo.com      NaN      NaN     Sabah  36.0
# 3  1982-09-20  2017-11-02    yahoo.com      NaN      NaN     Sabah  36.0
# 4  1982-09-20  2017-11-02    yahoo.com      NaN      NaN     Sabah  36.0
#
# [5 rows x 34 columns]

# %%
nba.columns
# Out:
# Index(['customerid', 'receiptid', 'productid', 'category', 'subcategory',
#        'prodname', 'prodqty', 'produnitprice', 'produnitdiscount',
#        'productdetailsid', 'submissionid', 'datetimeissued', 'receiptno',
#        'retailer', 'retailertype', 'retailerarea', 'retailercity',
#        'retailerstate', 'total', 'status', 'campaignid', 'retailerid',
#        'clientid', 'membershipid', 'names', 'gender', 'race', 'dob',
#        'joineddate', 'emaildomain', 'city', 'postcode', 'state', 'age'],
#       dtype='object')
